# %%
import pandas as pd 

df = pd.read_csv('../data/covid_19_indonesia_time_series_all.csv')
df = df[df['Location'] != 'Indonesia']
df.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
# 6  3/3/2020             ID-JB   Jawa Barat          1           1
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 3              0                 1            1             0
# 4              0                 2           43            20
# 6              0                 0            1             1
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# ...

# %%
df.isnull().sum()
# Out:
# Date                               0
# Location ISO Code                  0
# Location                           0
# New Cases                          0
# New Deaths                         0
# New Recovered                      0
# New Active Cases                   0
# Total Cases                        0
# Total Deaths                       0
# Total Recovered                    0
# Total Active Cases                 0
# Location Level                     0
# City or Regency                30893
# Province                           0
# Country                            0
# Continent                          0
# Island                             0
# Time Zone                          0
# Special Status                 26335
# Total Regencies                    0
# Total Cities                     901
# Total Districts                    0
# Total Urban Villages             904
# Total Rural Villages             929
# Area (km2)                         0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
df.head()
# Out:
#         Date Location ISO Code     Location  New Cases  New Deaths  \
# 0 2020-03-01             ID-JK  DKI Jakarta          2           0
# 1 2020-03-02             ID-JK  DKI Jakarta          2           0
# 3 2020-03-02             ID-RI         Riau          1           0
# 4 2020-03-03             ID-JK  DKI Jakarta          2           0
# 6 2020-03-03             ID-JB   Jawa Barat          1           1
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 3              0                 1            1             0
# 4              0                 2           43            20
# 6              0                 0            1             1
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# ...

# %%
df = df[['Date', 'Location', 'New Cases', 'New Deaths', 'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths', 'Total Recovered']]
df.head()
# Out:
#         Date     Location  New Cases  New Deaths  New Recovered  \
# 0 2020-03-01  DKI Jakarta          2           0              0
# 1 2020-03-02  DKI Jakarta          2           0              0
# 3 2020-03-02         Riau          1           0              0
# 4 2020-03-03  DKI Jakarta          2           0              0
# 6 2020-03-03   Jawa Barat          1           1              0
#
#    New Active Cases  Total Cases  Total Deaths  Total Recovered
# 0                 2           39            20               75
# 1                 2           41            20               75
# 3                 1            1             0                1
# 4                 2           43            20               75
# 6                 0            1             1               60

# %%
df.describe()
# Out:
#                                 Date     New Cases    New Deaths  \
# count                          30893  30893.000000  30893.000000
# mean   2021-06-18 01:54:03.647428352    207.079565      5.108568
# min              2020-03-01 00:00:00      0.000000      0.000000
# 25%              2020-11-03 00:00:00      3.000000      0.000000
# 50%              2021-06-18 00:00:00     24.000000      0.000000
# 75%              2022-01-31 00:00:00    113.000000      3.000000
# max              2022-09-15 00:00:00  16251.000000    545.000000
# std                              NaN    771.874452     22.344819
#
#        New Recovered  New Active Cases   Total Cases  Total Deaths  \
# count   30893.000000      30893.000000  3.089300e+04  30893.000000
# mean      200.840093          1.130903  8.204233e+04   2354.077202
# min         0.000000     -19976.000000  1.000000e+00      0.000000
# 25%         2.000000        -12.000000  4.905000e+03    121.000000
# ...

# %%
df['New Cases'] = df['New Cases'].apply(lambda x: x if x >= 0 else 0)
df['New Deaths'] = df['New Deaths'].apply(lambda x: x if x >= 0 else 0)
df.to_csv('../data/covid_19_indonesia_time_series_all_clean.csv', index=False)
